# %%
import numpy as np
import requests
from collections import Counter
import re
import pandas as pd

def compute_similarity(word, model, word2idx):
    if word not in word2idx:
        return []

    word_vector = model.W1[word2idx[word]]
    similarities = {}

    for other_word, idx in word2idx.items():
        if other_word != word:
            other_vector = model.W1[idx]
            similarity = np.dot(word_vector, other_vector) / (np.linalg.norm(word_vector) * np.linalg.norm(other_vector))
            similarities[other_word] = similarity

    sorted_similarities = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
    return sorted_similarities

if __name__ == "__main__":
    API_KEY = "xxxxx"  # Replace with your NewsAPI key

    models = {}
    word2idxs = {}
    sample_words = ["los", "angeles", "tribune"]  # Example words for similarity computation
    results = []
    metrics = []

    for window_size in [1, 2, 3]:
        for embedding_dim in [50, 100, 200]:
            print(f"Training model with window size {window_size} and embedding dim {embedding_dim}...")
            model, word2idx = train_model(API_KEY, window_size, embedding_dim)
            models[(window_size, embedding_dim)] = model
            word2idxs[(window_size, embedding_dim)] = word2idx

            avg_similarity = 0
            count = 0

            similarity_details = []

            for sample_word in sample_words:
                if sample_word in word2idx:
                    similar_words = compute_similarity(sample_word, model, word2idx)
                    if similar_words:
                        word_sim_avg = sum(sim[1] for sim in similar_words) / len(similar_words)
                        avg_similarity += word_sim_avg
                        count += 1
                        similarity_details.append((sample_word, similar_words))

            avg_similarity = avg_similarity / count if count > 0 else 0
            results.append((window_size, embedding_dim, avg_similarity))
            metrics.append({
                "Window Size": window_size,
                "Embedding Dim": embedding_dim,
                "Avg Similarity": avg_similarity,
                "Similarity Details": similarity_details
            })

    # Menemukan konfigurasi terbaik berdasarkan rata-rata nilai similaritas tertinggi
    best_config = max(results, key=lambda x: x[2])
    print(f"\nBest configuration: Window Size {best_config[0]}, Embedding Dim {best_config[1]} with Avg Similarity {best_config[2]:.4f}")

    # Menampilkan metrik dalam bentuk tabel
    metrics_df = pd.DataFrame(metrics)
    print("\nSimilarity Metrics:")
    print(metrics_df)

    # Menampilkan semua hasil similaritas untuk setiap kata dalam setiap konfigurasi
    for metric in metrics:
        print(f"\nWindow Size: {metric['Window Size']}, Embedding Dim: {metric['Embedding Dim']}")
        for word, similarities in metric["Similarity Details"]:
            print(f"Similar words for '{word}':")
            for similar_word, similarity in similarities:
                print(f"  {similar_word}: {similarity:.4f}")
# Out:
# Training model with window size 1 and embedding dim 50...
# Training model with window size 1 and embedding dim 100...
# Training model with window size 1 and embedding dim 200...
# Training model with window size 2 and embedding dim 50...
# Training model with window size 2 and embedding dim 100...
# Training model with window size 2 and embedding dim 200...
# Training model with window size 3 and embedding dim 50...
# Training model with window size 3 and embedding dim 100...
# Training model with window size 3 and embedding dim 200...
#
# Best configuration: Window Size 3, Embedding Dim 50 with Avg Similarity 0.2964
#
# Similarity Metrics:
#    Window Size  Embedding Dim  Avg Similarity  \
# 0            1             50       -0.067213
# 1            1            100       -0.075282
# 2            1            200       -0.074420
# 3            2             50        0.102038
# 4            2            100        0.123060
# 5            2            200        0.103807
# 6            3             50        0.296440
# 7            3            100        0.277101
# 8            3            200        0.234825
#
#                                   Similarity Details
# 0  [(los, [('bbccom', 0.25423493524775237), ('liv...
# 1  [(los, [('about', 0.2379952160792587), ('angel...
# 2  [(los, [('live', 0.3120004451767033), ('cnn', ...
# 3  [(los, [('angeles', 0.852492453772507), ('abou...
# 4  [(los, [('angeles', 0.790685578545063), ('abou...
# 5  [(los, [('angeles', 0.7647177158152986), ('abo...
# 6  [(los, [('angeles', 0.7416841089655448), ('tri...
# 7  [(los, [('angeles', 0.726352943471783), ('trib...
# 8  [(los, [('tribune', 0.6512618033829615), ('ang...
#
# Window Size: 1, Embedding Dim: 50
# Similar words for 'los':
#   bbccom: 0.2542
#   live: 0.1692
#   about: 0.1590
#   angeles: 0.1335
#   cnn: 0.0555
#   star: -0.0018
#   new: -0.1408
#   updates: -0.1758
#   tribune: -0.2392
#   says: -0.2917
#   source: -0.3839
#   post: -0.4967
# Similar words for 'angeles':
#   cnn: 0.2433
#   about: 0.2344
#   tribune: 0.2052
#   bbccom: 0.1376
#   los: 0.1335
#   live: -0.1248
#   updates: -0.2029
#   says: -0.3473
#   new: -0.3900
#   star: -0.4618
#   source: -0.4692
#   post: -0.6252
# Similar words for 'tribune':
#   live: 0.7757
#   cnn: 0.3985
#   post: 0.3507
#   new: 0.2982
#   angeles: 0.2052
#   updates: 0.0736
#   source: 0.0667
#   bbccom: -0.0806
#   los: -0.2392
#   star: -0.4613
#   about: -0.5302
#   says: -0.6514
#
# Window Size: 1, Embedding Dim: 100
# Similar words for 'los':
#   about: 0.2380
#   angeles: 0.2247
#   live: 0.2198
#   cnn: 0.1129
#   updates: -0.0203
#   bbccom: -0.0248
#   star: -0.1093
#   tribune: -0.2424
#   new: -0.3164
#   says: -0.3719
#   source: -0.4281
#   post: -0.6175
# Similar words for 'angeles':
#   about: 0.2705
#   los: 0.2247
#   tribune: 0.2235
#   cnn: 0.1814
#   updates: 0.1006
#   bbccom: -0.0484
#   live: -0.1366
#   new: -0.3679
#   star: -0.3850
#   says: -0.4286
#   source: -0.5280
#   post: -0.6622
# Similar words for 'tribune':
#   live: 0.7210
#   new: 0.2452
#   post: 0.2343
#   angeles: 0.2235
#   cnn: 0.2101
#   bbccom: 0.0919
#   updates: -0.0149
#   source: -0.1644
#   los: -0.2424
#   about: -0.3078
#   star: -0.3200
#   says: -0.4954
#
# Window Size: 1, Embedding Dim: 200
# Similar words for 'los':
#   live: 0.3120
#   cnn: 0.2002
#   angeles: 0.1823
#   about: 0.1510
#   updates: 0.0163
#   bbccom: -0.0718
#   star: -0.1643
#   tribune: -0.1989
#   new: -0.3053
#   says: -0.4009
#   source: -0.4504
#   post: -0.5829
# Similar words for 'angeles':
#   about: 0.2536
#   tribune: 0.2040
#   los: 0.1823
#   cnn: 0.1518
#   updates: 0.0215
#   bbccom: -0.0841
#   live: -0.1637
#   says: -0.3694
#   new: -0.4066
#   star: -0.4345
#   source: -0.4992
#   post: -0.6214
# Similar words for 'tribune':
#   live: 0.6866
#   cnn: 0.2771
#   post: 0.2677
#   angeles: 0.2040
#   new: 0.2039
#   bbccom: 0.0589
#   updates: -0.0034
#   source: -0.0192
#   los: -0.1989
#   star: -0.3115
#   about: -0.3129
#   says: -0.4531
#
# Window Size: 2, Embedding Dim: 50
# Similar words for 'los':
#   angeles: 0.8525
#   about: 0.4621
#   tribune: 0.3855
#   live: 0.2918
#   cnn: 0.0663
#   new: -0.0081
#   updates: -0.0884
#   star: -0.1291
#   bbccom: -0.1508
#   says: -0.2219
#   post: -0.3614
#   source: -0.4517
# Similar words for 'angeles':
#   los: 0.8525
#   about: 0.5240
#   live: 0.3242
#   tribune: 0.3063
#   cnn: 0.1534
#   new: 0.0416
#   star: -0.0060
#   updates: -0.0342
#   bbccom: -0.0607
#   says: -0.1938
#   post: -0.3253
#   source: -0.3553
# Similar words for 'tribune':
#   live: 0.7110
#   new: 0.5461
#   los: 0.3855
#   angeles: 0.3063
#   post: 0.1790
#   star: 0.1469
#   says: 0.0360
#   about: 0.0099
#   updates: -0.0523
#   cnn: -0.0960
#   bbccom: -0.1439
#   source: -0.2287
#
# Window Size: 2, Embedding Dim: 100
# Similar words for 'los':
#   angeles: 0.7907
#   about: 0.4093
#   live: 0.3336
#   tribune: 0.3057
#   cnn: 0.2015
#   bbccom: 0.1865
#   new: 0.1432
#   star: 0.0346
#   updates: -0.0811
#   says: -0.1762
#   source: -0.3781
#   post: -0.3848
# Similar words for 'angeles':
#   los: 0.7907
#   about: 0.4342
#   live: 0.3618
#   tribune: 0.3043
#   cnn: 0.1977
#   bbccom: 0.1267
#   new: 0.1188
#   star: 0.0492
#   updates: 0.0103
#   says: -0.1628
#   source: -0.3550
#   post: -0.4077
# Similar words for 'tribune':
#   live: 0.6894
#   new: 0.4719
#   los: 0.3057
#   angeles: 0.3043
#   post: 0.1292
#   star: 0.1018
#   bbccom: 0.0367
#   says: 0.0187
#   updates: 0.0000
#   about: -0.0280
#   cnn: -0.1432
#   source: -0.3093
#
# Window Size: 2, Embedding Dim: 200
# Similar words for 'los':
#   angeles: 0.7647
#   about: 0.4205
#   live: 0.3002
#   tribune: 0.2803
#   cnn: 0.1826
#   new: 0.0900
#   star: 0.0208
#   updates: -0.0234
#   bbccom: -0.0253
#   says: -0.0738
#   source: -0.3261
#   post: -0.3483
# Similar words for 'angeles':
#   los: 0.7647
#   about: 0.3933
#   tribune: 0.2747
#   live: 0.2730
#   cnn: 0.1952
#   new: 0.0878
#   star: 0.0042
#   says: -0.0303
#   updates: -0.0493
#   bbccom: -0.0496
#   source: -0.3095
#   post: -0.3293
# Similar words for 'tribune':
#   live: 0.6770
#   new: 0.3854
#   los: 0.2803
#   angeles: 0.2747
#   post: 0.1168
#   star: 0.0933
#   updates: 0.0463
#   about: 0.0253
#   bbccom: -0.0254
#   says: -0.0350
#   cnn: -0.1724
#   source: -0.4165
#
# Window Size: 3, Embedding Dim: 50
# Similar words for 'los':
#   angeles: 0.7417
#   tribune: 0.7242
#   new: 0.5241
#   about: 0.4143
#   live: 0.3974
#   post: 0.2517
#   source: 0.2493
#   star: 0.2340
#   cnn: 0.0709
#   bbccom: 0.0496
#   says: 0.0324
#   updates: 0.0140
# Similar words for 'angeles':
#   new: 0.7781
#   los: 0.7417
#   tribune: 0.6853
#   about: 0.4236
#   star: 0.3450
#   live: 0.2535
#   says: 0.1882
#   source: 0.1506
#   bbccom: 0.0834
#   post: 0.0777
#   updates: -0.0578
#   cnn: -0.1532
# Similar words for 'tribune':
#   los: 0.7242
#   live: 0.7169
#   angeles: 0.6853
#   star: 0.5905
#   new: 0.5107
#   about: 0.2894
#   cnn: 0.1472
#   bbccom: 0.1384
#   updates: 0.0419
#   source: -0.0693
#   says: -0.1031
#   post: -0.2199
#
# Window Size: 3, Embedding Dim: 100
# Similar words for 'los':
#   angeles: 0.7264
#   tribune: 0.6737
#   new: 0.4691
#   live: 0.3802
#   about: 0.3490
#   source: 0.2616
#   post: 0.2343
#   star: 0.1897
#   updates: 0.1305
#   cnn: 0.1048
#   says: 0.0679
#   bbccom: 0.0318
# Similar words for 'angeles':
#   los: 0.7264
#   new: 0.7150
#   tribune: 0.5850
#   about: 0.4246
#   star: 0.2704
#   says: 0.2160
#   live: 0.1951
#   source: 0.1744
#   bbccom: 0.1350
#   post: 0.0449
#   updates: 0.0254
#   cnn: -0.0798
# Similar words for 'tribune':
#   live: 0.7327
#   los: 0.6737
#   angeles: 0.5850
#   star: 0.5650
#   new: 0.4751
#   cnn: 0.1589
#   about: 0.0983
#   bbccom: 0.0214
#   updates: -0.0361
#   source: -0.0580
#   says: -0.0955
#   post: -0.1962
#
# Window Size: 3, Embedding Dim: 200
# Similar words for 'los':
#   tribune: 0.6513
#   angeles: 0.5673
#   live: 0.3538
#   about: 0.2991
#   new: 0.2845
#   post: 0.2526
#   source: 0.2385
#   star: 0.1156
#   cnn: 0.0941
#   updates: 0.0632
#   bbccom: 0.0296
#   says: -0.0141
# Similar words for 'angeles':
#   new: 0.6550
#   los: 0.5673
#   tribune: 0.4930
#   about: 0.3361
#   says: 0.3048
#   star: 0.2188
#   source: 0.2060
#   live: 0.1546
#   bbccom: 0.0411
#   updates: 0.0081
#   post: -0.0235
#   cnn: -0.0855
# Similar words for 'tribune':
#   live: 0.7287
#   los: 0.6513
#   star: 0.5276
#   angeles: 0.4930
#   new: 0.3971
#   cnn: 0.1514
#   about: 0.0599
#   updates: 0.0071
#   bbccom: -0.0481
#   source: -0.0632
#   says: -0.1055
#   post: -0.1569
